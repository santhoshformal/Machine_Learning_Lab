# %%
pip install seaborn
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# ...

# %%
conda install seaborn
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install seaborn')
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /usr/lib/python3/dist-packages/IPython/core/magics/packaging.py:26, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
# ...

# %%
sudo install python-seaborn
# Out:
#   Cell In[3], line 1
#     sudo install python-seaborn
#          ^
# SyntaxError: invalid syntax

# %%
apt install python-seaborn
# Out:
#   Cell In[4], line 1
#     apt install python-seaborn
#         ^
# SyntaxError: invalid syntax

# %%
apt-install python-seaborn
# Out:
#   Cell In[5], line 1
#     apt-install python-seaborn
#                 ^
# SyntaxError: invalid syntax

# %%
apt install python3-seaborn
# Out:
#   Cell In[6], line 1
#     apt install python3-seaborn
#         ^
# SyntaxError: invalid syntax

# %%
apt-install python3-seaborn
# Out:
#   Cell In[7], line 1
#     apt-install python3-seaborn
#                 ^
# SyntaxError: invalid syntax

# %%
# !pip install seaborn
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("Car_sales.csv")
df.columns = df.columns.str.lower()
sns.pairplot(df)
plt.show()

# %%
import pandas as pd
df = pd.read_csv("Car_sales.csv")
num_attributes = df.shape[1]
print("Number of attributes:", num_attributes)
# Out:
# Number of attributes: 15

# %%
df_final=df.drop_duplicates()
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df_final.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
#finding column with most missing values

# %%
print(df_final.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
print(df_final.isnull().sum().idxmax())
# Out:
# Manufacturer

# %%
# print(df_final.evaluate(df_final))

# %%
#min engine size

# %%
print(df_final["Engine size"].min())
# Out:
# .

# %%
# imputing missing values in engine column

# %%
# df_final["Engine size"].fillna(df_final["Engine size"].mean(),inplace=True)

# %%
df["Engine size"]=pd.to_numeric(df["Engine size"],errors="coerce")
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
import pandas as pd
import numpy as np
df_final["Engine size"].replace(".",np.nan,inplace=True)
df_final["Engine size"]=pd.to_numeric(df["Engine size"],errors="coerce")
Mean=df_final["Engine size"].mean()
df_final["Engine size"].fillna(Mean,inplace=True)
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
print(df_final["Engine size"].min())
# Out:
# 1.0

# %%
print(df_final["Engine size"].max())
# Out:
# 8.0
